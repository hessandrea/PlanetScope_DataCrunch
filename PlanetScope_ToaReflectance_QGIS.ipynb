# %% [markdown]
# <a href="https://colab.research.google.com/github/hessandrea/PlanetScope_DataCrunch/blob/master/PlanetScope_ToaReflectance_QGIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install rasterio
import rasterio
import numpy as np
import os
# Out:
# Collecting rasterio
#   Downloading https://files.pythonhosted.org/packages/be/e5/7052a3eef72af7e883a280d8dff64f4ea44cb92ec25ffb1d00ce27bc1a12/rasterio-1.1.2-cp36-cp36m-manylinux1_x86_64.whl (18.0MB)
#      |████████████████████████████████| 18.0MB 239kB/s
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Collecting affine
#   Downloading https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Collecting snuggs>=1.4.1
#   Downloading https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from rasterio) (7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from rasterio) (1.17.5)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from rasterio) (19.3.0)
# Collecting click-plugins
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.6/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.6)
# Installing collected packages: cligj, affine, snuggs, click-plugins, rasterio
# Successfully installed affine-2.3.0 click-plugins-1.1.1 cligj-0.5.0 rasterio-1.1.2 snuggs-1.4.7

# %%
SearchDirectory = "/content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files"
OutDirectory = "/content/drive/My Drive/PlanetScope/Reflectances"

# %%
if len("/content/drive/My Drive/PlanetScope") > 1:
    SearchDirectory = "/content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files"
    print("I'm looking for tifs in ", SearchDirectory)
else:
    print("Please tell me the directory to look in")
    sys.exit()
# Out:
# I'm looking for tifs in  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files

# %%
import os

for subdir, dirs, files in os.walk(SearchDirectory):
    for file in files:
        #print os.path.join(subdir, file)
        print("new iteration")
        filepath = subdir + os.sep + file

        if filepath.endswith("Analytic_metadata_clip.xml"):
            #print (filepath)
            tileCode = (filepath.split("/")[-1])[0:30]
            print(tileCode)
            
            filename =  SearchDirectory +"/" + tileCode  + "_BGRN_Analytic_clip.tif"
            print("using tif file: ", filename)
            xmlfile =  SearchDirectory  +"/"+ tileCode  + "_BGRN_Analytic_metadata_clip.xml"
            print("using meta file: ", xmlfile)
            output_file =  OutDirectory  +"/"+ tileCode + "_refl.tif"
            print ("calculating TOA and saving it into ", output_file)

            # Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
            with rasterio.open(filename) as src:
                band_blue_radiance = src.read(1)
                
            with rasterio.open(filename) as src:
                band_green_radiance = src.read(2)

            with rasterio.open(filename) as src:
                band_red_radiance = src.read(3)

            with rasterio.open(filename) as src:
                band_nir_radiance = src.read(4)

            from xml.dom import minidom

            xmldoc = minidom.parse(xmlfile)
            nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

            # XML parser refers to bands by numbers 1-4
            coeffs = {}
            for node in nodes:
                bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
                if bn in ['1', '2', '3', '4']:
                    i = int(bn)
                    value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
                    coeffs[i] = float(value)

            print ("Conversion coefficients:", coeffs)

            # Multiply the Digital Number (DN) values in each band by the TOA reflectance coefficients
            band_blue_reflectance = band_blue_radiance * coeffs[1]
            band_green_reflectance = band_green_radiance * coeffs[2]
            band_red_reflectance = band_red_radiance * coeffs[3]
            band_nir_reflectance = band_nir_radiance * coeffs[4]

            import numpy as np
            print ("Red band radiance is from {} to {}".format(np.amin(band_red_radiance), np.amax(band_red_radiance)))
            print ("Red band reflectance is from {} to {}".format(np.amin(band_red_reflectance), np.amax(band_red_reflectance)))

            kwargs = src.meta
            kwargs.update(
                dtype=rasterio.uint16,
                count = 4)

            print ("Before Scaling, red band reflectance is from {} to {}".format(np.amin(band_red_reflectance), np.amax(band_red_reflectance)))

            # Here we include a fixed scaling factor. This is common practice.
            scale = 10000
            blue_ref_scaled = scale * band_blue_reflectance
            green_ref_scaled = scale * band_green_reflectance
            red_ref_scaled = scale * band_red_reflectance
            nir_ref_scaled = scale * band_nir_reflectance

            print ("After Scaling, red band reflectance is from {} to {}".format(np.amin(red_ref_scaled), np.amax(red_ref_scaled)))

            # Write band calculations to a new raster file

            print("writing reflectance file to: ", output_file)

            with rasterio.open(output_file, 'w', **kwargs) as dst:
                    dst.write_band(1, blue_ref_scaled.astype(rasterio.uint16))
                    dst.write_band(2, green_ref_scaled.astype(rasterio.uint16))
                    dst.write_band(3, red_ref_scaled.astype(rasterio.uint16))
                    dst.write_band(4, nir_ref_scaled.astype(rasterio.uint16))
# Out:
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 295133_3744207_2016-11-17_0c45
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744207_2016-11-17_0c45_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744207_2016-11-17_0c45_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744207_2016-11-17_0c45_refl.tif
# Conversion coefficients: {1: 2.78575476294e-05, 2: 2.98808250245e-05, 3: 3.30857807302e-05, 4: 5.06799890116e-05}
# Red band radiance is from 0 to 20760
# Red band reflectance is from 0.0 to 0.686860807958952
# Before Scaling, red band reflectance is from 0.0 to 0.686860807958952
# After Scaling, red band reflectance is from 0.0 to 6868.60807958952
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744207_2016-11-17_0c45_refl.tif
# new iteration
# new iteration
# 293857_3744307_2016-11-15_0e1f
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744307_2016-11-15_0e1f_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744307_2016-11-15_0e1f_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744307_2016-11-15_0e1f_refl.tif
# Conversion coefficients: {1: 2.20211596601e-05, 2: 2.30586364207e-05, 3: 2.58676462724e-05, 4: 3.83870947983e-05}
# Red band radiance is from 0 to 25969
# Red band reflectance is from 0.0 to 0.6717569060479556
# Before Scaling, red band reflectance is from 0.0 to 0.6717569060479556
# After Scaling, red band reflectance is from 0.0 to 6717.569060479555
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744307_2016-11-15_0e1f_refl.tif
# new iteration
# new iteration
# new iteration
# 287002_3744307_2016-11-07_0c78
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/287002_3744307_2016-11-07_0c78_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/287002_3744307_2016-11-07_0c78_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/287002_3744307_2016-11-07_0c78_refl.tif
# Conversion coefficients: {1: 1.78018857913e-05, 2: 1.90948263469e-05, 3: 2.11428980652e-05, 4: 3.23861736966e-05}
# Red band radiance is from 0 to 22436
# Red band reflectance is from 0.0 to 0.47436206099082723
# Before Scaling, red band reflectance is from 0.0 to 0.47436206099082723
# After Scaling, red band reflectance is from 0.0 to 4743.620609908272
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/287002_3744307_2016-11-07_0c78_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 293857_3744306_2016-11-15_0e1f
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744306_2016-11-15_0e1f_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744306_2016-11-15_0e1f_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744306_2016-11-15_0e1f_refl.tif
# Conversion coefficients: {1: 2.20057473127e-05, 2: 2.30424979556e-05, 3: 2.58495418147e-05, 4: 3.83602281277e-05}
# Red band radiance is from 0 to 19494
# Red band reflectance is from 0.0 to 0.5039109681357619
# Before Scaling, red band reflectance is from 0.0 to 0.5039109681357619
# After Scaling, red band reflectance is from 0.0 to 5039.109681357619
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744306_2016-11-15_0e1f_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 293857_3744507_2016-11-15_0e1f
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744507_2016-11-15_0e1f_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744507_2016-11-15_0e1f_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744507_2016-11-15_0e1f_refl.tif
# Conversion coefficients: {1: 2.20990746108e-05, 2: 2.31402221567e-05, 3: 2.59591708067e-05, 4: 3.85229154655e-05}
# Red band radiance is from 0 to 15772
# Red band reflectance is from 0.0 to 0.4094280419632724
# Before Scaling, red band reflectance is from 0.0 to 0.4094280419632724
# After Scaling, red band reflectance is from 0.0 to 4094.2804196327243
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744507_2016-11-15_0e1f_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 293857_3744407_2016-11-15_0e1f
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744407_2016-11-15_0e1f_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744407_2016-11-15_0e1f_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744407_2016-11-15_0e1f_refl.tif
# Conversion coefficients: {1: 2.20677370256e-05, 2: 2.31074081726e-05, 3: 2.59223594134e-05, 4: 3.84682880584e-05}
# Red band radiance is from 0 to 27794
# Red band reflectance is from 0.0 to 0.7204860575360396
# Before Scaling, red band reflectance is from 0.0 to 0.7204860575360396
# After Scaling, red band reflectance is from 0.0 to 7204.860575360395
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744407_2016-11-15_0e1f_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 295133_3744307_2016-11-17_0c45
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744307_2016-11-17_0c45_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744307_2016-11-17_0c45_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744307_2016-11-17_0c45_refl.tif
# Conversion coefficients: {1: 2.80149154063e-05, 2: 3.0049622331e-05, 3: 3.32726828879e-05, 4: 5.09662811616e-05}
# Red band radiance is from 0 to 21695
# Red band reflectance is from 0.0 to 0.7218508552529904
# Before Scaling, red band reflectance is from 0.0 to 0.7218508552529904
# After Scaling, red band reflectance is from 0.0 to 7218.508552529905
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744307_2016-11-17_0c45_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 295133_3744407_2016-11-17_0c45
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744407_2016-11-17_0c45_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744407_2016-11-17_0c45_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744407_2016-11-17_0c45_refl.tif
# Conversion coefficients: {1: 2.80149154063e-05, 2: 3.0049622331e-05, 3: 3.32726828879e-05, 4: 5.09662811616e-05}
# Red band radiance is from 0 to 8906
# Red band reflectance is from 0.0 to 0.29632651379963737
# Before Scaling, red band reflectance is from 0.0 to 0.29632651379963737
# After Scaling, red band reflectance is from 0.0 to 2963.2651379963736
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744407_2016-11-17_0c45_refl.tif
# new iteration
# new iteration
# 287002_3744407_2016-11-07_0c78
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/287002_3744407_2016-11-07_0c78_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/287002_3744407_2016-11-07_0c78_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/287002_3744407_2016-11-07_0c78_refl.tif
# Conversion coefficients: {1: 1.78193097797e-05, 2: 1.91135158294e-05, 3: 2.11635921431e-05, 4: 3.24178723785e-05}
# Red band radiance is from 0 to 27494
# Red band reflectance is from 0.0 to 0.5818718023823913
# Before Scaling, red band reflectance is from 0.0 to 0.5818718023823913
# After Scaling, red band reflectance is from 0.0 to 5818.718023823913
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/287002_3744407_2016-11-07_0c78_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 287002_3744507_2016-11-07_0c78
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/287002_3744507_2016-11-07_0c78_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/287002_3744507_2016-11-07_0c78_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/287002_3744507_2016-11-07_0c78_refl.tif
# Conversion coefficients: {1: 1.78309648029e-05, 2: 1.91260173501e-05, 3: 2.11774345511e-05, 4: 3.24390758403e-05}
# Red band radiance is from 0 to 7049
# Red band reflectance is from 0.0 to 0.1492797361507039
# Before Scaling, red band reflectance is from 0.0 to 0.1492797361507039
# After Scaling, red band reflectance is from 0.0 to 1492.7973615070389
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/287002_3744507_2016-11-07_0c78_refl.tif
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# new iteration
# 293857_3744207_2016-11-15_0e1f
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744207_2016-11-15_0e1f_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744207_2016-11-15_0e1f_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744207_2016-11-15_0e1f_refl.tif
# Conversion coefficients: {1: 2.19750913521e-05, 2: 2.30103977092e-05, 3: 2.5813531107e-05, 4: 3.83067889226e-05}
# Red band radiance is from 0 to 28692
# Red band reflectance is from 0.0 to 0.740641834522044
# Before Scaling, red band reflectance is from 0.0 to 0.740641834522044
# After Scaling, red band reflectance is from 0.0 to 7406.41834522044
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744207_2016-11-15_0e1f_refl.tif
# new iteration
# new iteration
# 295133_3744206_2016-11-17_0c45
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744206_2016-11-17_0c45_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744206_2016-11-17_0c45_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744206_2016-11-17_0c45_refl.tif
# Conversion coefficients: {1: 2.78964033007e-05, 2: 2.99225027604e-05, 3: 3.31319287341e-05, 4: 5.07506773944e-05}
# Red band radiance is from 0 to 8965
# Red band reflectance is from 0.0 to 0.2970277411012065
# Before Scaling, red band reflectance is from 0.0 to 0.2970277411012065
# After Scaling, red band reflectance is from 0.0 to 2970.277411012065
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744206_2016-11-17_0c45_refl.tif
# new iteration
# new iteration
# 293857_3744206_2016-11-15_0e1f
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744206_2016-11-15_0e1f_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/293857_3744206_2016-11-15_0e1f_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744206_2016-11-15_0e1f_refl.tif
# Conversion coefficients: {1: 2.19750913521e-05, 2: 2.30103977092e-05, 3: 2.5813531107e-05, 4: 3.83067889226e-05}
# Red band radiance is from 0 to 23659
# Red band reflectance is from 0.0 to 0.610722332460513
# Before Scaling, red band reflectance is from 0.0 to 0.610722332460513
# After Scaling, red band reflectance is from 0.0 to 6107.22332460513
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/293857_3744206_2016-11-15_0e1f_refl.tif
# new iteration
# 295133_3744306_2016-11-17_0c45
# using tif file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744306_2016-11-17_0c45_BGRN_Analytic_clip.tif
# using meta file:  /content/drive/My Drive/PlanetScope/MecBa_Nov2016_01_PSOrthoTile_QGIS/files/295133_3744306_2016-11-17_0c45_BGRN_Analytic_metadata_clip.xml
# calculating TOA and saving it into  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744306_2016-11-17_0c45_refl.tif
# Conversion coefficients: {1: 2.80945801916e-05, 2: 3.01350731231e-05, 3: 3.33672989558e-05, 4: 5.11112117383e-05}
# Red band radiance is from 0 to 20305
# Red band reflectance is from 0.0 to 0.677523005297519
# Before Scaling, red band reflectance is from 0.0 to 0.677523005297519
# After Scaling, red band reflectance is from 0.0 to 6775.230052975189
# writing reflectance file to:  /content/drive/My Drive/PlanetScope/Reflectances/295133_3744306_2016-11-17_0c45_refl.tif
# new iteration
# new iteration
# new iteration

# %%
 
for root, dirs, files in os.walk(SearchDirectory):
     print("                  new iteration")
     print(os.path.basename(root))
     image_files = [1]
     for file in files:
         #if file.endswith(("BGRN_Analytic.tif")):
         if ((os.path.basename(root)).startswith("MecBa"))  and (file.endswith("Analytic_clip.tif")):
             print("Discovered this tif: ", os.path.join(root, file))
             image_files.append(os.path.join(root, file))

     
         filedirectory =  os.path.basename(root)
         print(filedirectory)
         filename =  filedirectory  + "_BGRN_Analytic.tif"
         print("using tif file: ", filename)
         xmlfile =  filedirectory  + "_BGRN_Analytic_metadata.xml"
         print("using meta file: ", xmlfile)
         output_file =  filedirectory + "_refl.tif"
         print ("calculating TOA and saving it into ", output_file)
         #pdf_bytes = img2pdf.convert(image_files)
         #file = open(output_file,"wb")
         #file.write(pdf_bytes)

         # Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
         with rasterio.open(filename) as src:
             band_blue_radiance = src.read(1)
            
         with rasterio.open(filename) as src:
             band_green_radiance = src.read(2)

         with rasterio.open(filename) as src:
             band_red_radiance = src.read(3)

         with rasterio.open(filename) as src:
             band_nir_radiance = src.read(4)

         from xml.dom import minidom

         xmldoc = minidom.parse(xmlfile)
         nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

         # XML parser refers to bands by numbers 1-4
         coeffs = {}
         for node in nodes:
             bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
             if bn in ['1', '2', '3', '4']:
                 i = int(bn)
                 value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
                 coeffs[i] = float(value)

         print ("Conversion coefficients:", coeffs)

         # Multiply the Digital Number (DN) values in each band by the TOA reflectance coefficients
         band_blue_reflectance = band_blue_radiance * coeffs[1]
         band_green_reflectance = band_green_radiance * coeffs[2]
         band_red_reflectance = band_red_radiance * coeffs[3]
         band_nir_reflectance = band_nir_radiance * coeffs[4]

         import numpy as np
         print ("Red band radiance is from {} to {}".format(np.amin(band_red_radiance), np.amax(band_red_radiance)))
         print ("Red band reflectance is from {} to {}".format(np.amin(band_red_reflectance), np.amax(band_red_reflectance)))

         kwargs = src.meta
         kwargs.update(
             dtype=rasterio.uint16,
             count = 4)

         print ("Before Scaling, red band reflectance is from {} to {}".format(np.amin(band_red_reflectance), np.amax(band_red_reflectance)))

         # Here we include a fixed scaling factor. This is common practice.
         scale = 10000
         blue_ref_scaled = scale * band_blue_reflectance
         green_ref_scaled = scale * band_green_reflectance
         red_ref_scaled = scale * band_red_reflectance
         nir_ref_scaled = scale * band_nir_reflectance

         print ("After Scaling, red band reflectance is from {} to {}".format(np.amin(red_ref_scaled), np.amax(red_ref_scaled)))

        # Write band calculations to a new raster file

         print("writing reflectance file to: ", output_file)

         with rasterio.open(output_file, 'w', **kwargs) as dst:
                 dst.write_band(1, blue_ref_scaled.astype(rasterio.uint16))
                 dst.write_band(2, green_ref_scaled.astype(rasterio.uint16))
                 dst.write_band(3, red_ref_scaled.astype(rasterio.uint16))
                 dst.write_band(4, nir_ref_scaled.astype(rasterio.uint16))

    #print(dst)
     else:
         print ("Couldn't find any tifs")
# Out:
#                   new iteration
# MecBa_Nov2016_01_PSOrthoTile_QGIS
# MecBa_Nov2016_01_PSOrthoTile_QGIS
# using tif file:  MecBa_Nov2016_01_PSOrthoTile_QGIS_BGRN_Analytic.tif
# using meta file:  MecBa_Nov2016_01_PSOrthoTile_QGIS_BGRN_Analytic_metadata.xml
# calculating TOA and saving it into  MecBa_Nov2016_01_PSOrthoTile_QGIS_refl.tif
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: MecBa_Nov2016_01_PSOrthoTile_QGIS_BGRN_Analytic.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-28-afae2774d0ec> in <module>()
#      24
#      25          # Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
# ---> 26          with rasterio.open(filename) as src:
#      27              band_blue_radiance = src.read(1)
#      28
#
# /usr/local/lib/python3.6/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     443
#     444         with env_ctor(session=session):
# --> 445             return f(*args, **kwds)
#     446
#     447     return wrapper
#
# /usr/local/lib/python3.6/dist-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     217         # None.
#     218         if mode == 'r':
# --> 219             s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     220         elif mode == 'r+':
#     221             s = get_writer_for_path(path)(path, mode, driver=driver, sharing=sharing, **kwargs)
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: MecBa_Nov2016_01_PSOrthoTile_QGIS_BGRN_Analytic.tif: No such file or directory

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

"""
The reflectance values will range from 0 to 1. You want to use a diverging color scheme to visualize the data,
and you want to center the colorbar at a defined midpoint. The class below allows you to normalize the colorbar.
"""

class MidpointNormalize(colors.Normalize):
    """
    Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)
    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))
    Credit: Joe Kington, http://chris35wills.github.io/matplotlib_diverging_colorbar/
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))


# Set min/max values from reflectance range for image (excluding NAN)
min=np.nanmin(band_nir_reflectance)
max=np.nanmax(band_nir_reflectance)
mid=0.20

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

# diverging color scheme chosen from https://matplotlib.org/users/colormaps.html
# note that appending '_r' to the color scheme name reverses it!
cmap = plt.cm.get_cmap('RdGy_r')

cax = ax.imshow(band_nir_reflectance, cmap=cmap, clim=(min, max), norm=MidpointNormalize(midpoint=mid,vmin=min, vmax=max))

ax.axis('off')
ax.set_title('NIR Reflectance', fontsize=18, fontweight='bold')

cbar = fig.colorbar(cax, orientation='horizontal', shrink=0.65)

#fig.savefig("data/ref-fig.png", dpi=200, bbox_inches='tight', pad_inches=0.7)

plt.show()
